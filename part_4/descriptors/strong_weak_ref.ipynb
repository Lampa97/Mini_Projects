# %%
import ctypes

def ref_count(address):
    return ctypes.c_long.from_address(address).value

# %%
class Person:
    def __init__(self, name):
        self.name = name

    def __repr__(self):
        return f'Person(name={self.name})'

# %%
p1 = Person('Guido')
p2 = p1

# %%
p1 is p2, id(p1), id(p2)
# Out:
# (True, 2005603030352, 2005603030352)

# %%
ref_count(id(p1))
# Out:
# 2

# %%
del p2

# %%
ref_count(id(p1))
# Out:
# 1

# %%
p1_id = id(p1)

# %%
ref_count(p1_id)
# Out:
# 1

# %%
del p1

# %%
ref_count(p1_id)
# Out:
# 0

# %%
import weakref

# %%
p1 = Person('Guido')
p1_id = id(p1)

# %%
ref_count(p1_id)
# Out:
# 1

# %%
p2 = p1
ref_count(p1_id)
# Out:
# 2

# %%
weak1 = weakref.ref(p1)

# %%
ref_count(p1_id)
# Out:
# 2

# %%
weak1
# Out:
# <weakref at 0x000001D2F74FE2F0; to 'Person' at 0x000001D2F74B1090>

# %%
hex(p1_id)
# Out:
# '0x1d2f74b1090'

# %%
weak1 is p1
# Out:
# False

# %%
weak1() is p1
# Out:
# True

# %%
print(weak1())
# Out:
# Person(name=Guido)

# %%
ref_count(p1_id)
# Out:
# 2

# %%
p3 = weak1()

# %%
ref_count(p1_id)
# Out:
# 3

# %%
del p3

# %%
ref_count(p1_id)
# Out:
# 2

# %%
del p2
ref_count(p1_id)
# Out:
# 1

# %%
print(weak1())
# Out:
# Person(name=Guido)

# %%
weak1
# Out:
# <weakref at 0x000001D2F74FE2F0; to 'Person' at 0x000001D2F74B1090>

# %%
del p1

# %%
ref_count(p1_id)
# Out:
# -145552512

# %%
weak1
# Out:
# <weakref at 0x000001D2F74FE2F0; dead>

# %%
result = weak1()

# %%
print(result)
# Out:
# None

# %%
hex(id(None))
# Out:
# '0x7ffa7a3e81f0'

# %%
p = None

# %%
hex(id(None))
# Out:
# '0x7ffa7a3e81f0'

# %%
l = 'python'
try:
    w = weakref.ref(l)
except TypeError as ex:
    print(ex)
# Out:
# cannot create weak reference to 'str' object

# %%
p1 = Person('Guido')

# %%
d = weakref.WeakKeyDictionary()

# %%
ref_count(id(p1))
# Out:
# 1

# %%
n = {p1: 'Guido'}

# %%
ref_count(id(p1))
# Out:
# 2

# %%
del n

# %%
ref_count(id(p1))
# Out:
# 1

# %%
d[p1] = 'Guido'

# %%
ref_count(id(p1))
# Out:
# 1

# %%
d

# %%
weakref.getweakrefcount(p1)
# Out:
# 1

# %%
d2 = weakref.WeakKeyDictionary()
d2[p1] = 'Guido'

# %%
ref_count(id(p1)), weakref.getweakrefcount(p1)
# Out:
# (1, 2)

# %%
p1.__weakref__
# Out:
# <weakref at 0x000001D2F75927F0; to 'Person' at 0x000001D2F74B1090>

# %%
hex(id(p1))
# Out:
# '0x1d2f74b1090'

# %%
list(d.keyrefs())
# Out:
# [<weakref at 0x000001D2F73F3740; to 'Person' at 0x000001D2F74B1090>]

# %%
del p1

# %%
list(d.keyrefs())
# Out:
# []

# %%
d['python'] = 'test'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 d['python'] = 'test'
#
# File c:\Users\CASPER\AppData\Local\Programs\Python\Python313\Lib\weakref.py:428, in WeakKeyDictionary.__setitem__(self, key, value)
#     427 def __setitem__(self, key, value):
# --> 428     self.data[ref(key, self._remove)] = value
#
# TypeError: cannot create weak reference to 'str' object

# %%
class Person:
    def __init__(self, name):
        self.name = name

# %%
p = Person('Alex')

# %%
hash(p)
# Out:
# 125350189838

# %%
d[p] = 'Alex'

# %%
list(d.keyrefs())
# Out:
# [<weakref at 0x000001D2F7C72F20; to 'Person' at 0x000001D2F741B0E0>]

# %%
class Person:
    def __init__(self, name):
        self.name = name

    def __eq__(self, other):
        return isinstance(other, Person) and self.name == other.name

# %%
p1 = Person('Guido')
p2 = Person('Guido')

# %%
p1 == p2
# Out:
# True

# %%
hash(p1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 hash(p1)
#
# TypeError: unhashable type: 'Person'

# %%
d = weakref.WeakKeyDictionary()

# %%
d[p1] = 'test'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 d[p1] = 'test'
#
# File c:\Users\CASPER\AppData\Local\Programs\Python\Python313\Lib\weakref.py:428, in WeakKeyDictionary.__setitem__(self, key, value)
#     427 def __setitem__(self, key, value):
# --> 428     self.data[ref(key, self._remove)] = value
#
# TypeError: unhashable type: 'Person'

# %%
class Person:
    def __init__(self, name):
        self.name = name

    def __eq__(self, other):
        return isinstance(other, Person) and self.name == other.name
    
    def __hash__(self):
        return hash(self.name)

# %%
p1 = Person('Guido')
p2 = Person('Guido')

# %%
p1 == p2
# Out:
# True

# %%
hash(p1)
# Out:
# 9016986579217174442

# %%
d[p1] = 'test'

# %%
list(d.keyrefs())
# Out:
# [<weakref at 0x000001D2F7D018A0; to 'Person' at 0x000001D2F741A3C0>]
