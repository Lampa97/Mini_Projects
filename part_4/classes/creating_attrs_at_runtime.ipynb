# %%
class Person:
    pass

# %%
p1 = Person()
p2 = Person()

p1.name = 'Alex'

# %%
p1.__dict__
# Out:
# {'name': 'Alex'}

# %%
p2.__dict__
# Out:
# {}

# %%
p1.say_hello = lambda: 'Hello!'

# %%
p1.say_hello
# Out:
# <function __main__.<lambda>()>

# %%
p1.__dict__
# Out:
# {'name': 'Alex', 'say_hello': <function __main__.<lambda>()>}

# %%
from types import MethodType

# %%
class Person:
    def __init__(self, name):
        self.name = name

# %%
p1 = Person('Eric')
p2 = Person('Alex')

# %%
p1.__dict__, p2.__dict__
# Out:
# ({'name': 'Eric'}, {'name': 'Alex'})

# %%
def say_hello(self):
    return f'{self.name} says hello!'

# %%
say_hello(p2)
# Out:
# 'Alex says hello!'

# %%
p1_say_hello = MethodType(say_hello, p1)

# %%
p1_say_hello
# Out:
# <bound method say_hello of <__main__.Person object at 0x000001DB9043A7B0>>

# %%
p1.p1_say_hello
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 p1.p1_say_hello
#
# AttributeError: 'Person' object has no attribute 'p1_say_hello'

# %%
p1.__dict__
# Out:
# {'name': 'Eric'}

# %%
p1.say_hello = p1_say_hello

# %%
p1.__dict__
# Out:
# {'name': 'Eric',
#  'say_hello': <bound method say_hello of <__main__.Person object at 0x000001DB9043A7B0>>}

# %%
hex(id(p1))
# Out:
# '0x1db9043a7b0'

# %%
p1.say_hello()
# Out:
# 'Eric says hello!'

# %%
getattr(p1, 'say_hello')()
# Out:
# 'Eric says hello!'

# %%
p1 = Person('Alex')
p1.__dict__
# Out:
# {'name': 'Alex'}

# %%
p1.say_hello = MethodType(lambda self: f'{self.name} says hello', p1)

# %%
p1.say_hello()
# Out:
# 'Alex says hello'

# %%
p1 = Person('Alex')
p2 = Person('Eric')

p1.say_hello = MethodType(lambda self: f'{self.name} says hello', p2)

# %%
p1.say_hello()
# Out:
# 'Eric says hello'

# %%
from types import MethodType

class Person:
    def __init__(self, name):
        self.name = name

    def register_do_work(self, func):
        setattr(self, '_do_work', MethodType(func, self))

    def do_work(self):
        do_work_method = getattr(self, '_do_work', None)

        if do_work_method:
            return do_work_method()
        else:
            raise AttributeError('You must first register a do_work method.')

# %%
math_teacher = Person('Eric')
english_teacher = Person('John')

# %%
math_teacher.do_work()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 math_teacher.do_work()
#
# Cell In[29], line 16, in Person.do_work(self)
#      14     return do_work_method()
#      15 else:
# ---> 16     raise AttributeError('You must first register a do_work method.')
#
# AttributeError: You must first register a do_work method.

# %%
def work_math(self):
    return f'{self.name} will teach differentials today.'

# %%
math_teacher.register_do_work(work_math)

# %%
math_teacher.__dict__
# Out:
# {'name': 'Eric',
#  '_do_work': <bound method work_math of <__main__.Person object at 0x000001DB9043BA10>>}

# %%
hex(id(math_teacher))
# Out:
# '0x1db9043ba10'

# %%
math_teacher.do_work()
# Out:
# 'Eric will teach differentials today.'

# %%
def work_english(self):
    return f'{self.name} will analyze Hamlet today'

# %%
english_teacher.register_do_work(work_english)

# %%
english_teacher.do_work()
# Out:
# 'John will analyze Hamlet today'

# %%
persons = [math_teacher, english_teacher]

# %%
for person in persons:
    print(person.do_work())
# Out:
# Eric will teach differentials today.
# John will analyze Hamlet today
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
