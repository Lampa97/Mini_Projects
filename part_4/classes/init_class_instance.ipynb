# %%
class Person:
    def __init__(self):
        print(f'Initializing a new Person object: {self}')

# %%
p = Person()
# Out:
# Initializing a new Person object: <__main__.Person object at 0x0000025E14158C20>

# %%
hex(id(p))
# Out:
# '0x25e14158c20'

# %%
class Person:
    def __init__(self, name):
        self.name = name

# %%
p = Person('Eric')

# %%
p.__dict__
# Out:
# {'name': 'Eric'}

# %%
class Person:
    def init(self, name):
        self.name = name

# %%
p = Person()

# %%
p.__dict__
# Out:
# {}

# %%
p.init('Eric')

# %%
p.__dict__
# Out:
# {'name': 'Eric'}
