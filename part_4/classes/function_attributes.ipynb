# %%
class Person:
    def say_hello():
        print('Hello')

# %%
Person.say_hello
# Out:
# <function __main__.Person.say_hello()>

# %%
type(Person.say_hello)
# Out:
# function

# %%
Person.say_hello()
# Out:
# Hello

# %%
p = Person()

# %%
hex(id(p))
# Out:
# '0x237ba24a120'

# %%
p.say_hello
# Out:
# <bound method Person.say_hello of <__main__.Person object at 0x00000237BA24A120>>

# %%
type(p.say_hello)
# Out:
# method

# %%
type(p.say_hello) is type(Person.say_hello)
# Out:
# False

# %%
p.say_hello()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 p.say_hello()
#
# TypeError: Person.say_hello() takes 0 positional arguments but 1 was given

# %%
class Person: 
    def say_hello(*args):
        print('say_hello args:', args)

# %%
Person.say_hello()
# Out:
# say_hello args: ()

# %%
p = Person()

# %%
hex(id(p))
# Out:
# '0x237ba24acf0'

# %%
p.say_hello()
# Out:
# say_hello args: (<__main__.Person object at 0x00000237BA24ACF0>,)

# %%
class Person:
    def set_name(instance_obj, new_name):
        instance_obj.name = new_name
        # settatr(instance_obj, 'name', new_name)

# %%
p = Person()

# %%
p.set_name('Alex')

# %%
p.__dict__
# Out:
# {'name': 'Alex'}

# %%
p = Person()

# %%
Person.set_name(p, 'John')

# %%
p.__dict__
# Out:
# {'name': 'John'}

# %%
class Person:
    def set_name(self, new_name):
        self.name = new_name
        # settatr(self, 'name', new_name)

# %%
class Person:
    def say_hello(self):
        print(f'{self} says hello')

# %%
Person.say_hello, hex(id(Person.say_hello))
# Out:
# (<function __main__.Person.say_hello(self)>, '0x237ba947ce0')

# %%
p = Person()

# %%
p.say_hello
# Out:
# <bound method Person.say_hello of <__main__.Person object at 0x00000237BA24ACF0>>

# %%
m_hello = p.say_hello

# %%
m_hello
# Out:
# <bound method Person.say_hello of <__main__.Person object at 0x00000237BA24ACF0>>

# %%
m_hello.__func__
# Out:
# <function __main__.Person.say_hello(self)>

# %%
hex(id(p))
# Out:
# '0x237ba24acf0'

# %%
m_hello.__self__

# %%
class Person:
    def say_hello(self):
        print(f'instance method called from {self}')

# %%
p = Person()
hex(id(p))
# Out:
# '0x237ba24b620'

# %%
p.say_hello()
# Out:
# instance method called from <__main__.Person object at 0x00000237BA24B620>

# %%
Person.do_work = lambda self:  f'do_work called from {self}'

# %%
Person.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'say_hello': <function __main__.Person.say_hello(self)>,
#               '__static_attributes__': (),
#               '__dict__': <attribute '__dict__' of 'Person' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Person' objects>,
#               '__doc__': None,
#               'do_work': <function __main__.<lambda>(self)>})

# %%
p.say_hello
# Out:
# <bound method Person.say_hello of <__main__.Person object at 0x00000237BA24B620>>

# %%
p.do_work
# Out:
# <bound method <lambda> of <__main__.Person object at 0x00000237BA24B620>>

# %%
p.do_work()
# Out:
# 'do_work called from <__main__.Person object at 0x00000237BA24B620>'

# %%
p.other_func = lambda *args: print(f'other_func called with {args}')

# %%
p.other_func
# Out:
# <function __main__.<lambda>(*args)>

# %%
p.__dict__
# Out:
# {'other_func': <function __main__.<lambda>(*args)>}

# %%
p.other_func()
# Out:
# other_func called with ()
