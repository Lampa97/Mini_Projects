# %%
class Person:
    def work(self):
        return 'Person works...'
    
class Student(Person):
    def work(self):
        result = super().work()
        return f'Student works... and {result}'

# %%
s = Student()
s.work()
# Out:
# 'Student works... and Person works...'

# %%
class Person:
    def work(self):
        return 'Person works...'
    
class Student(Person):
    pass

class PythonStudent(Student):
    def work(self):
        result = super().work()
        return f'PythonStudent codes... and {result}'

# %%
ps = PythonStudent()
ps.work()
# Out:
# 'PythonStudent codes... and Person works...'

# %%
class Person:
    def work(self):
        return 'Person works...'
    
class Student(Person):
    def work(self):
        result = super().work()
        return f'Student studies... and {result}'

class PythonStudent(Student):
    def work(self):
        result = super().work()
        return f'PythonStudent codes... and {result}'

# %%
ps = PythonStudent()
ps.work()
# Out:
# 'PythonStudent codes... and Student studies... and Person works...'

# %%
class Person:
    def work(self):
        return 'Person works...'

class Student(Person):
    def study(self):
        return 'Student studies...'
    
class PythonStudent(Student):
    def code(self):
        result_1 = self.work()
        result_2 = self.study()
        return f'{result_1} and {result_2} and PythonStudent codes...'

# %%
ps = PythonStudent()
ps.code()
# Out:
# 'Person works... and Student studies... and PythonStudent codes...'

# %%
class Person:
    def work(self):
        return f'{self} works...'
    
class Student(Person):
    def work(self):
        result = super().work()
        return f'{self} studies... and {result}'

class PythonStudent(Student):
    def work(self):
        result = super().work()
        return f'{self} codes... and {result}'

# %%
ps = PythonStudent()
ps.work()
# Out:
# '<__main__.PythonStudent object at 0x000001998BC402F0> codes... and <__main__.PythonStudent object at 0x000001998BC402F0> studies... and <__main__.PythonStudent object at 0x000001998BC402F0> works...'

# %%
class Person:
    def set_name(self, value):
        print('Setting name using Person set_name method...')
        self.name = value
    
class Student(Person):
    def set_name(self, value):
        print('Student class delegating back to parent...')
        super().set_name(value)

# %%
s = Student()

# %%
s.set_name('Alex')
# Out:
# Student class delegating back to parent...
# Setting name using Person set_name method...

# %%
s.__dict__
# Out:
# {'name': 'Alex'}

# %%
class Person:
    def __init__(self, name):
        self.name = name

class Student(Person):
    def __init__(self, name, student_number):
        super().__init__(name)
        self.student_number = student_number

# %%
s = Student('Python', 30)

# %%
s.__dict__
# Out:
# {'name': 'Python', 'student_number': 30}

# %%
class Person:
    def __init__(self, name):
        self.name = name

class Student(Person):
    pass

# %%
s = Student()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 s = Student()
#
# TypeError: Person.__init__() missing 1 required positional argument: 'name'

# %%
s = Student('Guido')

# %%
s.__dict__
# Out:
# {'name': 'Guido'}

# %%
class Person:
    pass

# %%
Person.__init__ is object.__init__
# Out:
# True

# %%
p = Person()

# %%
from math import pi
from numbers import Real

class Circle:
    def __init__(self, r):
        self.radius = r
        self._area = None
        self._perimeter = None
    
    @property
    def radius(self):
        return self._r
    
    @radius.setter
    def radius(self, r):
        if isinstance(r, Real) and r > 0:
            self._r = r
            self._area = None
            self._perimeter = None
        else:
            raise ValueError('Radius must be a positive real number.')

    @property
    def area(self):
        if self._area is None:
            self._area = pi * self.radius ** 2
        return self._area
    
    @property
    def perimeter(self):
        if self._perimeter is None:
            self._perimeter = 2 * pi * self.radius
        return self._perimeter

# %%
class UnitCircle(Circle):
    def __init__(self):
        super().__init__(1)

# %%
u = UnitCircle()

# %%
u.radius, u.area, u.perimeter
# Out:
# (1, 3.141592653589793, 6.283185307179586)

# %%
u.radius
# Out:
# 1

# %%
class UnitCircle(Circle):
    def __init__(self):
        super().__init__(1)
    
    @property
    def radius(self):
        return super().radius

# %%
u = UnitCircle()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 u = UnitCircle()
#
# Cell In[52], line 3, in UnitCircle.__init__(self)
#       2 def __init__(self):
# ----> 3     super().__init__(1)
#
# Cell In[45], line 6, in Circle.__init__(self, r)
#       5 def __init__(self, r):
# ----> 6     self.radius = r
#       7     self._area = None
#       8     self._perimeter = None
#
# AttributeError: property 'radius' of 'UnitCircle' object has no setter

# %%
from math import pi
from numbers import Real

class Circle:
    def __init__(self, r):
        self._set_radius(r)
        self._area = None
        self._perimeter = None
    
    @property
    def radius(self):
        return self._r
    
    def _set_radius(self, r):
        if isinstance(r, Real) and r > 0:
            self._r = r
            self._area = None
            self._perimeter = None
        else:
            raise ValueError('Radius must be a positive real number.')


    @radius.setter
    def radius(self, r):
        self._set_radius(r)

    @property
    def area(self):
        if self._area is None:
            self._area = pi * self.radius ** 2
        return self._area
    
    @property
    def perimeter(self):
        if self._perimeter is None:
            self._perimeter = 2 * pi * self.radius
        return self._perimeter
    

class UnitCircle(Circle):
    def __init__(self):
        super().__init__(1)
    
    @property
    def radius(self):
        return super().radius

# %%
u = UnitCircle()

# %%
u.radius
# Out:
# 1

# %%
u.radius = 100
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 u.radius = 100
#
# AttributeError: property 'radius' of 'UnitCircle' object has no setter

# %%
u.set_radius(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 u.set_radius(10)
#
# AttributeError: 'UnitCircle' object has no attribute 'set_radius'

# %%
u.radius
# Out:
# 1
