# %%
class Location:
    __slots__ = 'name', '_longitude', '_latitude'

    def __init__(self, name, *, longitude, latitude):
        self._longitude = longitude
        self._latitude = latitude
        self.name = name

    @property
    def longitude(self):
        return self._longitude
    
    @property
    def latitude(self):
        return self._latitude

# %%
Location.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__slots__': ('name', '_longitude', '_latitude'),
#               '__init__': <function __main__.Location.__init__(self, name, longitude, latitude)>,
#               'longitude': <property at 0x1d1ffaa0040>,
#               'latitude': <property at 0x1d1ffb257b0>,
#               '__static_attributes__': ('_latitude', '_longitude', 'name'),
#               '_latitude': <member '_latitude' of 'Location' objects>,
#               '_longitude': <member '_longitude' of 'Location' objects>,
#               'name': <member 'name' of 'Location' objects>,
#               '__doc__': None})

# %%
Location.map_service = 'Google Maps'

# %%
Location.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__slots__': ('name', '_longitude', '_latitude'),
#               '__init__': <function __main__.Location.__init__(self, name, longitude, latitude)>,
#               'longitude': <property at 0x1d1ffaa0040>,
#               'latitude': <property at 0x1d1ffb257b0>,
#               '__static_attributes__': ('_latitude', '_longitude', 'name'),
#               '_latitude': <member '_latitude' of 'Location' objects>,
#               '_longitude': <member '_longitude' of 'Location' objects>,
#               'name': <member 'name' of 'Location' objects>,
#               '__doc__': None,
#               'map_service': 'Google Maps'})

# %%
l = Location('Mumbai', longitude=19.0760, latitude=72.8777)

# %%
l.name, l.longitude, l.latitude
# Out:
# ('Mumbai', 19.076, 72.8777)

# %%
l.__dict__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 l.__dict__
#
# AttributeError: 'Location' object has no attribute '__dict__'

# %%
l.map_link = 'https://..'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 l.map_link = 'https://..'
#
# AttributeError: 'Location' object has no attribute 'map_link' and no __dict__ for setting new attributes

# %%
del l.name

# %%
l.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 l.name
#
# AttributeError: 'Location' object has no attribute 'name'

# %%
l.name = 'Mumbai'

# %%
l.name
# Out:
# 'Mumbai'

# %%
del l.longitude
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 del l.longitude
#
# AttributeError: property 'longitude' of 'Location' object has no deleter

# %%
del l._longitude

# %%
l.longitude
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 l.longitude
#
# Cell In[1], line 11, in Location.longitude(self)
#       9 @property
#      10 def longitude(self):
# ---> 11     return self._longitude
#
# AttributeError: 'Location' object has no attribute '_longitude'
