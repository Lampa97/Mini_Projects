# %%
class Shape:
    pass

# %%
class Ellipse(Shape):
    pass

class Circle(Ellipse):
    pass

class Polygon(Shape):
    pass

class Rectangle(Polygon):
    pass

class Square(Rectangle):
    pass

class Triangle(Polygon):
    pass

# %%
issubclass(Ellipse, Shape)
# Out:
# True

# %%
issubclass(Circle, Shape)
# Out:
# True

# %%
issubclass(Polygon, Ellipse)
# Out:
# False

# %%
issubclass(Square, Shape)
# Out:
# True

# %%
s = Shape()
e = Circle()
sq = Square()

# %%
issubclass(e, s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 issubclass(e, s)
#
# TypeError: issubclass() arg 1 must be a class

# %%
isinstance(s, Shape)
# Out:
# True

# %%
isinstance(sq, Rectangle)
# Out:
# True

# %%
isinstance(sq, Shape)
# Out:
# True

# %%
type(Shape)
# Out:
# type

# %%
type(s)
# Out:
# __main__.Shape

# %%
sq = Square()
p = Polygon()

# %%
sq, p
# Out:
# (<__main__.Square at 0x1f12f3b0e10>, <__main__.Polygon at 0x1f12f1c9fd0>)

# %%
isinstance(sq, type(p))
# Out:
# True

# %%
issubclass(type(sq), type(p))
# Out:
# True

# %%
type(object)
# Out:
# type

# %%
class Person:
    pass

# %%
issubclass(Person, object)
# Out:
# True

# %%
issubclass(Square, object)
# Out:
# True

# %%
issubclass(Square, Square)
# Out:
# True

# %%
cls1 = Square
cls2 = Square

# %%
issubclass(cls1, cls2)
# Out:
# True
