# %%
a = 0.1

# %%
format(a, '.20f')
# Out:
# '0.10000000000000000555'

# %%
from datetime import datetime

# %%
now = datetime.utcnow()
# Out:
# C:\Users\CASPER\AppData\Local\Temp\ipykernel_30672\253522816.py:1: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   now = datetime.utcnow()

# %%
format(now, '%a %Y-%m-%d %I:%M %p')
# Out:
# 'Fri 2025-10-17 07:10 AM'

# %%
class Person:
    def __init__(self, name, dob):
        self.name = name
        self.dob = dob
    
    def __repr__(self):
        print('__repr__ called...')
        return f'Person(name={self.name}, dob={self.dob.isoformat()})'
    
    def __str__(self):
        print('__str__ was called...')
        return f'Person({self.name})'

    def __format__(self, date_format_spec):
        print(f'__format__ called with spec={date_format_spec}')
        dob = format(self.dob, date_format_spec)
        return f'Person(name={self.name}, dob={dob})'

# %%
from datetime import date

p = Person('Alex', date(1900, 10, 20))

# %%
str(p)
# Out:
# __str__ was called...
# 'Person(Alex)'

# %%
repr(p)
# Out:
# __repr__ called...
# 'Person(name=Alex, dob=1900-10-20)'

# %%
p
# Out:
# __repr__ called...
# Person(name=Alex, dob=1900-10-20)

# %%
format(p, '%B %d, %Y')
# Out:
# __format__ called with spec=%B %d, %Y
# 'Person(name=Alex, dob=October 20, 1900)'

# %%
format(p)
# Out:
# __format__ called with spec=
# 'Person(name=Alex, dob=1900-10-20)'

# %%
format(p.dob)
# Out:
# '1900-10-20'

# %%
str(p.dob)
# Out:
# '1900-10-20'
