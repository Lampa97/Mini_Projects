# %%
from enum import Enum

# %%
class Color(Enum):
    red = 1
    green = 2
    blue = 3

    def purecolor(self, value):
        return {self: value}

# %%
Color.red.purecolor(100), Color.blue.purecolor(255)
# Out:
# ({<Color.red: 1>: 100}, {<Color.blue: 3>: 255})

# %%
Color.red
# Out:
# <Color.red: 1>

# %%
class Color(Enum):
    red = 1
    green = 2
    blue = 3

    def __repr__(self):
        return f'{self.name} ({self.value})'

# %%
Color.red
# Out:
# red (1)

# %%
class Number(Enum):
    ONE = 1
    TWO = 2
    THREE = 3

# %%
Number.ONE > Number.TWO
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 Number.ONE > Number.TWO
#
# TypeError: '>' not supported between instances of 'Number' and 'Number'

# %%
class Number(Enum):
    ONE = 1
    TWO = 2
    THREE = 3

    def __lt__(self, other):
        return isinstance(other, Number) and self.value < other.value

# %%
Number.ONE < Number.TWO
# Out:
# True

# %%
Number.ONE > Number.TWO
# Out:
# False

# %%
Number.ONE == 1
# Out:
# False

# %%
class Number(Enum):
    ONE = 1
    TWO = 2
    THREE = 3

    def __lt__(self, other):
        return isinstance(other, Number) and self.value < other.value
    
    def __eq__(self, other):
        if isinstance(other, Number):
            return self is other
        elif isinstance(other, int):
            return self.value == other
        return False

# %%
Number.ONE is Number.ONE, Number.ONE == Number.ONE
# Out:
# (True, True)

# %%
Number.ONE == 1
# Out:
# True

# %%
Number.ONE == 1.0
# Out:
# False

# %%
hash(Number.ONE)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 hash(Number.ONE)
#
# TypeError: unhashable type: 'Number'

# %%
Number.ONE < Number.TWO, Number.TWO > Number.ONE
# Out:
# (True, True)

# %%
Number.ONE >= Number.ONE
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 Number.ONE >= Number.ONE
#
# TypeError: '>=' not supported between instances of 'Number' and 'Number'

# %%
from functools import total_ordering

@total_ordering
class Number(Enum):
    ONE = 1
    TWO = 2
    THREE = 3

    def __lt__(self, other):
        return isinstance(other, Number) and self.value < other.value

# %%
Number.ONE >= Number.TWO
# Out:
# False

# %%
class Phase(Enum):
    READY = 'ready'
    RUNNING = 'running'
    FINISHED = 'finished'

    def __str__(self):
        return self.value
    
    def __eq__(self, other):
        if isinstance(other, Phase):
            return self is other
        elif isinstance(other, str):
            return self.value == other
        return False
    
    def compare_phases(self, items, self_index, other):
        other_order_index = items.index(other)
        return self_index < other_order_index

    def __lt__(self, other):
        ordered_items = list(Phase)
        self_order_index = ordered_items.index(self)

        if isinstance(other, Phase):
           return self.compare_phases(ordered_items, self_order_index, other)
        
        if isinstance(other, str):
            try:
                other_member = Phase(other)
                return self.compare_phases(ordered_items, self_order_index, other_member)
            except ValueError:
                return False

# %%
Phase.READY == 'ready'
# Out:
# True

# %%
Phase.READY < Phase.RUNNING
# Out:
# True

# %%
Phase.READY < 'running'
# Out:
# True

# %%
class State(Enum):
    READY = 1
    BUSY = 0

# %%
bool(State.READY), bool(State.BUSY)
# Out:
# (True, True)

# %%
state = State.READY

# %%
if state is State.READY:
    print('system ready to process next item')
else:
    print('System is busy')
# Out:
# system ready to process next item

# %%
if state:
    print('system ready to process next item')
else:
    print('System is busy')
# Out:
# system ready to process next item

# %%
class State(Enum):
    READY = 1
    BUSY = 0

    def __bool__(self):
        return bool(self.value)

# %%
state = State.BUSY
if state:
    print('system ready to process next item')
else:
    print('System is busy')
# Out:
# System is busy

# %%
class Color(Enum):
    RED = 1
    GREEN = 2
    BLUE = 3

# %%
class ColorAlpha(Color):
    ALPHA = 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 class ColorAlpha(Color):
#       2     ALPHA = 4
#
# File c:\Users\CASPER\AppData\Local\Programs\Python\Python313\Lib\enum.py:487, in EnumType.__prepare__(metacls, cls, bases, **kwds)
#     484 @classmethod
#     485 def __prepare__(metacls, cls, bases, **kwds):
#     486     # check that previous enum members do not exist
# --> 487     metacls._check_for_existing_members_(cls, bases)
#     488     # create the namespace dict
#     489     enum_dict = EnumDict(cls)
#
# File c:\Users\CASPER\AppData\Local\Programs\Python\Python313\Lib\enum.py:937, in EnumType._check_for_existing_members_(mcls, class_name, bases)
#     935 for base in chain.__mro__:
#     936     if isinstance(base, EnumType) and base._member_names_:
# --> 937         raise TypeError(
#     938                 "<enum %r> cannot extend %r"
#     939                 % (class_name, base)
#     940                 )
#
# TypeError: <enum 'ColorAlpha'> cannot extend <enum 'Color'>

# %%
class ColorBase(Enum):
    def hello(self):
        return f'{str(self)} says hello'

# %%
class Color(ColorBase):
    RED = 'red'
    GREEN = 'green'
    BLUE = 'blue'

# %%
Color.RED.hello()
# Out:
# 'Color.RED says hello'

# %%
Color.BLUE.hello()
# Out:
# 'Color.BLUE says hello'

# %%
from functools import total_ordering
@total_ordering
class OrderedEnum(Enum):
    """Create an ordering based on the member values.
    So member values have to support rich comparisons."""

    def __lt__(self, other):
        if isinstance(other, OrderedEnum):
            return self.value < other.value
        return NotImplemented

# %%
class Number(OrderedEnum):
    ONE = 1
    TWO = 2
    THREE = 3

class Dimension(OrderedEnum):
    D1 = 1,
    D2 = 1, 1
    D3 = 1, 1, 1

# %%
Number.ONE < Number.TWO
# Out:
# True

# %%
Dimension.D2 > Dimension.D1
# Out:
# True

# %%
Dimension.D2 >= Dimension.D1
# Out:
# True

# %%
from http import HTTPStatus

# %%
type(HTTPStatus)
# Out:
# enum.EnumType

# %%
list(HTTPStatus)[0:10]
# Out:
# [<HTTPStatus.CONTINUE: 100>,
#  <HTTPStatus.SWITCHING_PROTOCOLS: 101>,
#  <HTTPStatus.PROCESSING: 102>,
#  <HTTPStatus.EARLY_HINTS: 103>,
#  <HTTPStatus.OK: 200>,
#  <HTTPStatus.CREATED: 201>,
#  <HTTPStatus.ACCEPTED: 202>,
#  <HTTPStatus.NON_AUTHORITATIVE_INFORMATION: 203>,
#  <HTTPStatus.NO_CONTENT: 204>,
#  <HTTPStatus.RESET_CONTENT: 205>]

# %%
HTTPStatus(400)
# Out:
# <HTTPStatus.BAD_REQUEST: 400>

# %%
HTTPStatus.OK, HTTPStatus.OK.name, HTTPStatus.OK.value
# Out:
# (<HTTPStatus.OK: 200>, 'OK', 200)

# %%
HTTPStatus.NOT_FOUND.value, HTTPStatus.NOT_FOUND.name, HTTPStatus.NOT_FOUND.phrase
# Out:
# (404, 'NOT_FOUND', 'Not Found')

# %%
class AppStatus(Enum):
    OK = (0, 'No problem!')
    FAILED = (1, 'Crap!')

# %%
AppStatus.OK.value[1]
# Out:
# 'No problem!'

# %%
class AppStatus(Enum):
    OK = (0, 'No problem!')
    FAILED = (1, 'Crap!')

    @property
    def code(self):
        return self.value[0]
    
    @property
    def phrase(self):
        return self.value[1]

# %%
AppStatus.OK.code, AppStatus.OK.phrase, AppStatus.OK.name
# Out:
# (0, 'No problem!', 'OK')

# %%
HTTPStatus(200)
# Out:
# <HTTPStatus.OK: 200>

# %%
AppStatus(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 AppStatus(0)
#
# File c:\Users\CASPER\AppData\Local\Programs\Python\Python313\Lib\enum.py:726, in EnumType.__call__(cls, value, names, module, qualname, type, start, boundary, *values)
#     724     if names is not _not_given:
#     725         value = (value, names) + values
# --> 726     return cls.__new__(cls, value)
#     727 # otherwise, functional API: we're creating a new Enum type
#     728 if names is _not_given and type is None:
#     729     # no body? no data-type? possibly wrong usage
#
# File c:\Users\CASPER\AppData\Local\Programs\Python\Python313\Lib\enum.py:1199, in Enum.__new__(cls, value)
#    1197 ve_exc = ValueError("%r is not a valid %s" % (value, cls.__qualname__))
#    1198 if result is None and exc is None:
# -> 1199     raise ve_exc
#    1200 elif exc is None:
#    1201     exc = TypeError(
#    1202             'error in %s._missing_: returned %r instead of None or a valid member'
#    1203             % (cls.__name__, result)
#    1204             )
#
# ValueError: 0 is not a valid AppStatus

# %%
class AppStatus(Enum):
    OK = (0, 'No problem!')
    FAILED = (1, 'Crap!')

    def __new__(cls, member_value, member_phrase):
       print(cls, member_value, member_phrase)
       member =  object.__new__(cls)

       member._value_ = member_value
       member.phrase = member_phrase

       return member
# Out:
# <enum 'AppStatus'> 0 No problem!
# <enum 'AppStatus'> 1 Crap!

# %%
AppStatus.OK.value, AppStatus.OK.name, AppStatus.OK.phrase
# Out:
# (0, 'OK', 'No problem!')

# %%
AppStatus(0)
# Out:
# <AppStatus.OK: 0>

# %%
AppStatus(1)
# Out:
# <AppStatus.FAILED: 1>

# %%
class TwoValueEnum(Enum):
       
    def __new__(cls, member_value, member_phrase):
       print(cls, member_value, member_phrase)
       member =  object.__new__(cls)

       member._value_ = member_value
       member.phrase = member_phrase

       return member

# %%
class AppStatus(TwoValueEnum):
    OK = (0, 'No problem!')
    FAILED = (1, 'Crap!')
# Out:
# <enum 'AppStatus'> 0 No problem!
# <enum 'AppStatus'> 1 Crap!

# %%
AppStatus.FAILED.name, AppStatus.FAILED.value, AppStatus.FAILED.phrase
# Out:
# ('FAILED', 1, 'Crap!')
